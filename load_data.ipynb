# %%
import pandas as pd
import os
import re 
import numpy as np
import cv2
from matplotlib.pyplot import imread
import matplotlib.pyplot as plt
from zipfile import ZipFile
import shutil

# %% [markdown]
# ## Load Sensor Data

# %%
def read_data(data): 
    
    data.reset_index(inplace = True)
    data.rename(columns={'level_0': 'Time'}, inplace = True)
    data.rename(columns={'x-axis (deg/s).4': 'Raw Brainwave Signal '}, inplace = True)
    data.rename(columns={'Unnamed: 42': 'Tag'}, inplace = True)
    
    TimeStamp = data.iloc[:,0]
    ankle = data.iloc[: , 1:8]
    pocket = data.iloc[:, 8:15]
    waist = data.iloc[:,15:22]
    neck = data.iloc[:,22:29]
    wrist = data.iloc[:,29:36]
    EEG = data.iloc[:,36]
    Infraded = data.iloc[:,37:43]
    label = data.iloc[:,46]
        
    ankle.columns = ['X-axis Accelerometer (g)', 'Y-axis Accelerometer (g)' , 'Z-axis Accelerometer (g)',
                     'Roll Gyroscrope (deg/s)', 'Pitch Gyroscope (deg/s)', 'Yaw Gyroscope (deg/s)' ,'Luminosity (lux)']

    pocket.columns = ['X-axis Accelerometer (g)', 'Y-axis Accelerometer (g)' , 'Z-axis Accelerometer (g)',
                     'Roll Gyroscrope (deg/s)', 'Pitch Gyroscope (deg/s)', 'Yaw Gyroscope (deg/s)' ,'Luminosity (lux)']

    waist.columns = ['X-axis Accelerometer (g)', 'Y-axis Accelerometer (g)' , 'Z-axis Accelerometer (g)',
                     'Roll Gyroscrope (deg/s)', 'Pitch Gyroscope (deg/s)', 'Yaw Gyroscope (deg/s)' ,'Luminosity (lux)']

    neck.columns = ['X-axis Accelerometer (g)', 'Y-axis Accelerometer (g)' , 'Z-axis Accelerometer (g)',
                     'Roll Gyroscrope (deg/s)', 'Pitch Gyroscope (deg/s)', 'Yaw Gyroscope (deg/s)' ,'Luminosity (lux)']

    wrist.columns = ['X-axis Accelerometer (g)', 'Y-axis Accelerometer (g)' , 'Z-axis Accelerometer (g)',
                     'Roll Gyroscrope (deg/s)', 'Pitch Gyroscope (deg/s)', 'Yaw Gyroscope (deg/s)' ,'Luminosity (lux)']

    Infraded.columns = ['Infrared 1', 'Infrared 2', 'Infrared 3', 'Infrared 4', 'Infrared 5', 'Infrared 6']

    handled_data = pd.concat([TimeStamp, ankle,pocket,waist,neck,wrist,EEG,Infraded ], 
                            axis = 1, 
                            keys = ['TimeStamp','Wearable Ankle', 'Wearable Pocket','Wearable Waist', 
                                    'Wearable Neck', 'Wearable Wrist','EEG Headset'  ,'Infrared'],
                             
                            names = ['Deviece Name', 'Channel Name'])
    handled_data[('Tag' , 'Label')]= label
    
    return handled_data


def concat_data():
    concat_Sub = []
    list_Sub = []
    sum_shape = 0
    sum_csv = 0
    for sub_ in range(1,17 + 1 ) :
        Sub = 'Subject' + str(sub_)
        list_Sub.append(Sub)
        concat_Act = []
        list_Act = []
        for act_ in range(1,11+1):
            Act = 'Activity'+ str(act_)
            list_Act.append(Act)
            concat_Trial = []
            list_Trial  = []
            for trial_ in range(1,3+1):
                Trial = 'Trial'+ str(trial_)
                list_Trial.append(Trial)
                if ( (sub_ == 8 and act_ == 11) and ( trial_ == 2 or trial_ == 3) ) :
                    print('----------------------------NULL---------------------------------')
                    continue 
                else :
                    path = Sub + '/' + Act + '/' + Trial + '/' + Sub + Act + Trial + '.csv'
                data = pd.read_csv(path,skiprows=1)
                print('path : {} . Shape : ({},{})'.format(path, data.shape[0], data.shape[1]))
                sum_shape += data.shape[0]
                sum_csv +=1 
                handled  = read_data(data)
                concat_Trial.append(handled)
            TRIAL = pd.concat(concat_Trial,keys = list_Trial)
            concat_Act.append(TRIAL)
        ACT = pd.concat(concat_Act, keys = list_Act)
        concat_Sub.append(ACT)
    SUB = pd.concat(concat_Sub,keys = list_Sub)
    return SUB

# %%
SUB = concat_data()
# Out:
# path : Subject1/Activity1/Trial1/Subject1Activity1Trial1.csv . Shape : (195,43)
# path : Subject1/Activity1/Trial2/Subject1Activity1Trial2.csv . Shape : (193,43)
# path : Subject1/Activity1/Trial3/Subject1Activity1Trial3.csv . Shape : (194,43)
# path : Subject1/Activity2/Trial1/Subject1Activity2Trial1.csv . Shape : (157,43)
# path : Subject1/Activity2/Trial2/Subject1Activity2Trial2.csv . Shape : (195,43)
# path : Subject1/Activity2/Trial3/Subject1Activity2Trial3.csv . Shape : (194,43)
# path : Subject1/Activity3/Trial1/Subject1Activity3Trial1.csv . Shape : (192,43)
# path : Subject1/Activity3/Trial2/Subject1Activity3Trial2.csv . Shape : (191,43)
# path : Subject1/Activity3/Trial3/Subject1Activity3Trial3.csv . Shape : (190,43)
# path : Subject1/Activity4/Trial1/Subject1Activity4Trial1.csv . Shape : (189,43)
# path : Subject1/Activity4/Trial2/Subject1Activity4Trial2.csv . Shape : (191,43)
# path : Subject1/Activity4/Trial3/Subject1Activity4Trial3.csv . Shape : (193,43)
# path : Subject1/Activity5/Trial1/Subject1Activity5Trial1.csv . Shape : (189,43)
# path : Subject1/Activity5/Trial2/Subject1Activity5Trial2.csv . Shape : (182,43)
# path : Subject1/Activity5/Trial3/Subject1Activity5Trial3.csv . Shape : (187,43)
# path : Subject1/Activity6/Trial1/Subject1Activity6Trial1.csv . Shape : (1133,43)
# path : Subject1/Activity6/Trial2/Subject1Activity6Trial2.csv . Shape : (1124,43)
# path : Subject1/Activity6/Trial3/Subject1Activity6Trial3.csv . Shape : (1115,43)
# path : Subject1/Activity7/Trial1/Subject1Activity7Trial1.csv . Shape : (1121,43)
# path : Subject1/Activity7/Trial2/Subject1Activity7Trial2.csv . Shape : (1101,43)
# path : Subject1/Activity7/Trial3/Subject1Activity7Trial3.csv . Shape : (1084,43)
# path : Subject1/Activity8/Trial1/Subject1Activity8Trial1.csv . Shape : (1079,43)
# path : Subject1/Activity8/Trial2/Subject1Activity8Trial2.csv . Shape : (1088,43)
# path : Subject1/Activity8/Trial3/Subject1Activity8Trial3.csv . Shape : (1054,43)
# path : Subject1/Activity9/Trial1/Subject1Activity9Trial1.csv . Shape : (181,43)
# path : Subject1/Activity9/Trial2/Subject1Activity9Trial2.csv . Shape : (177,43)
# path : Subject1/Activity9/Trial3/Subject1Activity9Trial3.csv . Shape : (174,43)
# path : Subject1/Activity10/Trial1/Subject1Activity10Trial1.csv . Shape : (530,43)
# path : Subject1/Activity10/Trial2/Subject1Activity10Trial2.csv . Shape : (525,43)
# path : Subject1/Activity10/Trial3/Subject1Activity10Trial3.csv . Shape : (499,43)
# path : Subject1/Activity11/Trial1/Subject1Activity11Trial1.csv . Shape : (1062,43)
# path : Subject1/Activity11/Trial2/Subject1Activity11Trial2.csv . Shape : (1039,43)
# path : Subject1/Activity11/Trial3/Subject1Activity11Trial3.csv . Shape : (1014,43)
# path : Subject2/Activity1/Trial1/Subject2Activity1Trial1.csv . Shape : (171,43)
# path : Subject2/Activity1/Trial2/Subject2Activity1Trial2.csv . Shape : (171,43)
# path : Subject2/Activity1/Trial3/Subject2Activity1Trial3.csv . Shape : (175,43)
# path : Subject2/Activity2/Trial1/Subject2Activity2Trial1.csv . Shape : (174,43)
# path : Subject2/Activity2/Trial2/Subject2Activity2Trial2.csv . Shape : (168,43)
# path : Subject2/Activity2/Trial3/Subject2Activity2Trial3.csv . Shape : (175,43)
# path : Subject2/Activity3/Trial1/Subject2Activity3Trial1.csv . Shape : (177,43)
# path : Subject2/Activity3/Trial2/Subject2Activity3Trial2.csv . Shape : (173,43)
# path : Subject2/Activity3/Trial3/Subject2Activity3Trial3.csv . Shape : (177,43)
# path : Subject2/Activity4/Trial1/Subject2Activity4Trial1.csv . Shape : (180,43)
# path : Subject2/Activity4/Trial2/Subject2Activity4Trial2.csv . Shape : (167,43)
# path : Subject2/Activity4/Trial3/Subject2Activity4Trial3.csv . Shape : (168,43)
# path : Subject2/Activity5/Trial1/Subject2Activity5Trial1.csv . Shape : (168,43)
# path : Subject2/Activity5/Trial2/Subject2Activity5Trial2.csv . Shape : (140,43)
# path : Subject2/Activity5/Trial3/Subject2Activity5Trial3.csv . Shape : (147,43)
# path : Subject2/Activity6/Trial1/Subject2Activity6Trial1.csv . Shape : (1033,43)
# path : Subject2/Activity6/Trial2/Subject2Activity6Trial2.csv . Shape : (1062,43)
# path : Subject2/Activity6/Trial3/Subject2Activity6Trial3.csv . Shape : (1094,43)
# path : Subject2/Activity7/Trial1/Subject2Activity7Trial1.csv . Shape : (1063,43)
# path : Subject2/Activity7/Trial2/Subject2Activity7Trial2.csv . Shape : (1031,43)
# path : Subject2/Activity7/Trial3/Subject2Activity7Trial3.csv . Shape : (1030,43)
# path : Subject2/Activity8/Trial1/Subject2Activity8Trial1.csv . Shape : (1056,43)
# path : Subject2/Activity8/Trial2/Subject2Activity8Trial2.csv . Shape : (1041,43)
# path : Subject2/Activity8/Trial3/Subject2Activity8Trial3.csv . Shape : (1031,43)
# path : Subject2/Activity9/Trial1/Subject2Activity9Trial1.csv . Shape : (162,43)
# path : Subject2/Activity9/Trial2/Subject2Activity9Trial2.csv . Shape : (158,43)
# path : Subject2/Activity9/Trial3/Subject2Activity9Trial3.csv . Shape : (166,43)
# path : Subject2/Activity10/Trial1/Subject2Activity10Trial1.csv . Shape : (459,43)
# path : Subject2/Activity10/Trial2/Subject2Activity10Trial2.csv . Shape : (470,43)
# path : Subject2/Activity10/Trial3/Subject2Activity10Trial3.csv . Shape : (471,43)
# path : Subject2/Activity11/Trial1/Subject2Activity11Trial1.csv . Shape : (982,43)
# path : Subject2/Activity11/Trial2/Subject2Activity11Trial2.csv . Shape : (947,43)
# path : Subject2/Activity11/Trial3/Subject2Activity11Trial3.csv . Shape : (936,43)
# path : Subject3/Activity1/Trial1/Subject3Activity1Trial1.csv . Shape : (188,43)
# path : Subject3/Activity1/Trial2/Subject3Activity1Trial2.csv . Shape : (187,43)
# path : Subject3/Activity1/Trial3/Subject3Activity1Trial3.csv . Shape : (186,43)
# path : Subject3/Activity2/Trial1/Subject3Activity2Trial1.csv . Shape : (187,43)
# path : Subject3/Activity2/Trial2/Subject3Activity2Trial2.csv . Shape : (177,43)
# path : Subject3/Activity2/Trial3/Subject3Activity2Trial3.csv . Shape : (185,43)
# path : Subject3/Activity3/Trial1/Subject3Activity3Trial1.csv . Shape : (191,43)
# path : Subject3/Activity3/Trial2/Subject3Activity3Trial2.csv . Shape : (181,43)
# path : Subject3/Activity3/Trial3/Subject3Activity3Trial3.csv . Shape : (184,43)
# path : Subject3/Activity4/Trial1/Subject3Activity4Trial1.csv . Shape : (191,43)
# path : Subject3/Activity4/Trial2/Subject3Activity4Trial2.csv . Shape : (189,43)
# path : Subject3/Activity4/Trial3/Subject3Activity4Trial3.csv . Shape : (189,43)
# path : Subject3/Activity5/Trial1/Subject3Activity5Trial1.csv . Shape : (186,43)
# path : Subject3/Activity5/Trial2/Subject3Activity5Trial2.csv . Shape : (179,43)
# path : Subject3/Activity5/Trial3/Subject3Activity5Trial3.csv . Shape : (183,43)
# path : Subject3/Activity6/Trial1/Subject3Activity6Trial1.csv . Shape : (1124,43)
# path : Subject3/Activity6/Trial2/Subject3Activity6Trial2.csv . Shape : (1105,43)
# path : Subject3/Activity6/Trial3/Subject3Activity6Trial3.csv . Shape : (1064,43)
# path : Subject3/Activity7/Trial1/Subject3Activity7Trial1.csv . Shape : (1100,43)
# path : Subject3/Activity7/Trial2/Subject3Activity7Trial2.csv . Shape : (1067,43)
# path : Subject3/Activity7/Trial3/Subject3Activity7Trial3.csv . Shape : (1089,43)
# path : Subject3/Activity8/Trial1/Subject3Activity8Trial1.csv . Shape : (1088,43)
# path : Subject3/Activity8/Trial2/Subject3Activity8Trial2.csv . Shape : (1078,43)
# path : Subject3/Activity8/Trial3/Subject3Activity8Trial3.csv . Shape : (1071,43)
# path : Subject3/Activity9/Trial1/Subject3Activity9Trial1.csv . Shape : (176,43)
# path : Subject3/Activity9/Trial2/Subject3Activity9Trial2.csv . Shape : (175,43)
# path : Subject3/Activity9/Trial3/Subject3Activity9Trial3.csv . Shape : (169,43)
# path : Subject3/Activity10/Trial1/Subject3Activity10Trial1.csv . Shape : (526,43)
# path : Subject3/Activity10/Trial2/Subject3Activity10Trial2.csv . Shape : (517,43)
# path : Subject3/Activity10/Trial3/Subject3Activity10Trial3.csv . Shape : (536,43)
# path : Subject3/Activity11/Trial1/Subject3Activity11Trial1.csv . Shape : (1069,43)
# path : Subject3/Activity11/Trial2/Subject3Activity11Trial2.csv . Shape : (1070,43)
# path : Subject3/Activity11/Trial3/Subject3Activity11Trial3.csv . Shape : (1038,43)
# path : Subject4/Activity1/Trial1/Subject4Activity1Trial1.csv . Shape : (183,43)
# path : Subject4/Activity1/Trial2/Subject4Activity1Trial2.csv . Shape : (186,43)
# path : Subject4/Activity1/Trial3/Subject4Activity1Trial3.csv . Shape : (185,43)
# path : Subject4/Activity2/Trial1/Subject4Activity2Trial1.csv . Shape : (183,43)
# path : Subject4/Activity2/Trial2/Subject4Activity2Trial2.csv . Shape : (189,43)
# path : Subject4/Activity2/Trial3/Subject4Activity2Trial3.csv . Shape : (191,43)
# path : Subject4/Activity3/Trial1/Subject4Activity3Trial1.csv . Shape : (181,43)
# path : Subject4/Activity3/Trial2/Subject4Activity3Trial2.csv . Shape : (183,43)
# path : Subject4/Activity3/Trial3/Subject4Activity3Trial3.csv . Shape : (186,43)
# path : Subject4/Activity4/Trial1/Subject4Activity4Trial1.csv . Shape : (187,43)
# path : Subject4/Activity4/Trial2/Subject4Activity4Trial2.csv . Shape : (193,43)
# path : Subject4/Activity4/Trial3/Subject4Activity4Trial3.csv . Shape : (191,43)
# path : Subject4/Activity5/Trial1/Subject4Activity5Trial1.csv . Shape : (182,43)
# path : Subject4/Activity5/Trial2/Subject4Activity5Trial2.csv . Shape : (182,43)
# path : Subject4/Activity5/Trial3/Subject4Activity5Trial3.csv . Shape : (180,43)
# path : Subject4/Activity6/Trial1/Subject4Activity6Trial1.csv . Shape : (1089,43)
# path : Subject4/Activity6/Trial2/Subject4Activity6Trial2.csv . Shape : (1092,43)
# path : Subject4/Activity6/Trial3/Subject4Activity6Trial3.csv . Shape : (1089,43)
# path : Subject4/Activity7/Trial1/Subject4Activity7Trial1.csv . Shape : (1086,43)
# path : Subject4/Activity7/Trial2/Subject4Activity7Trial2.csv . Shape : (1066,43)
# path : Subject4/Activity7/Trial3/Subject4Activity7Trial3.csv . Shape : (1080,43)
# path : Subject4/Activity8/Trial1/Subject4Activity8Trial1.csv . Shape : (1078,43)
# path : Subject4/Activity8/Trial2/Subject4Activity8Trial2.csv . Shape : (1071,43)
# path : Subject4/Activity8/Trial3/Subject4Activity8Trial3.csv . Shape : (1057,43)
# path : Subject4/Activity9/Trial1/Subject4Activity9Trial1.csv . Shape : (178,43)
# path : Subject4/Activity9/Trial2/Subject4Activity9Trial2.csv . Shape : (179,43)
# path : Subject4/Activity9/Trial3/Subject4Activity9Trial3.csv . Shape : (180,43)
# path : Subject4/Activity10/Trial1/Subject4Activity10Trial1.csv . Shape : (533,43)
# path : Subject4/Activity10/Trial2/Subject4Activity10Trial2.csv . Shape : (529,43)
# path : Subject4/Activity10/Trial3/Subject4Activity10Trial3.csv . Shape : (536,43)
# path : Subject4/Activity11/Trial1/Subject4Activity11Trial1.csv . Shape : (1058,43)
# path : Subject4/Activity11/Trial2/Subject4Activity11Trial2.csv . Shape : (1064,43)
# path : Subject4/Activity11/Trial3/Subject4Activity11Trial3.csv . Shape : (1068,43)
# path : Subject5/Activity1/Trial1/Subject5Activity1Trial1.csv . Shape : (185,43)
# path : Subject5/Activity1/Trial2/Subject5Activity1Trial2.csv . Shape : (186,43)
# path : Subject5/Activity1/Trial3/Subject5Activity1Trial3.csv . Shape : (183,43)
# path : Subject5/Activity2/Trial1/Subject5Activity2Trial1.csv . Shape : (192,43)
# path : Subject5/Activity2/Trial2/Subject5Activity2Trial2.csv . Shape : (188,43)
# path : Subject5/Activity2/Trial3/Subject5Activity2Trial3.csv . Shape : (189,43)
# path : Subject5/Activity3/Trial1/Subject5Activity3Trial1.csv . Shape : (192,43)
# path : Subject5/Activity3/Trial2/Subject5Activity3Trial2.csv . Shape : (192,43)
# path : Subject5/Activity3/Trial3/Subject5Activity3Trial3.csv . Shape : (191,43)
# path : Subject5/Activity4/Trial1/Subject5Activity4Trial1.csv . Shape : (193,43)
# path : Subject5/Activity4/Trial2/Subject5Activity4Trial2.csv . Shape : (193,43)
# path : Subject5/Activity4/Trial3/Subject5Activity4Trial3.csv . Shape : (194,43)
# path : Subject5/Activity5/Trial1/Subject5Activity5Trial1.csv . Shape : (194,43)
# path : Subject5/Activity5/Trial2/Subject5Activity5Trial2.csv . Shape : (189,43)
# path : Subject5/Activity5/Trial3/Subject5Activity5Trial3.csv . Shape : (192,43)
# path : Subject5/Activity6/Trial1/Subject5Activity6Trial1.csv . Shape : (1096,43)
# path : Subject5/Activity6/Trial2/Subject5Activity6Trial2.csv . Shape : (1117,43)
# path : Subject5/Activity6/Trial3/Subject5Activity6Trial3.csv . Shape : (1112,43)
# path : Subject5/Activity7/Trial1/Subject5Activity7Trial1.csv . Shape : (1075,43)
# path : Subject5/Activity7/Trial2/Subject5Activity7Trial2.csv . Shape : (1126,43)
# path : Subject5/Activity7/Trial3/Subject5Activity7Trial3.csv . Shape : (1126,43)
# path : Subject5/Activity8/Trial1/Subject5Activity8Trial1.csv . Shape : (1093,43)
# path : Subject5/Activity8/Trial2/Subject5Activity8Trial2.csv . Shape : (1090,43)
# path : Subject5/Activity8/Trial3/Subject5Activity8Trial3.csv . Shape : (1109,43)
# path : Subject5/Activity9/Trial1/Subject5Activity9Trial1.csv . Shape : (186,43)
# path : Subject5/Activity9/Trial2/Subject5Activity9Trial2.csv . Shape : (193,43)
# path : Subject5/Activity9/Trial3/Subject5Activity9Trial3.csv . Shape : (187,43)
# path : Subject5/Activity10/Trial1/Subject5Activity10Trial1.csv . Shape : (566,43)
# path : Subject5/Activity10/Trial2/Subject5Activity10Trial2.csv . Shape : (556,43)
# path : Subject5/Activity10/Trial3/Subject5Activity10Trial3.csv . Shape : (563,43)
# path : Subject5/Activity11/Trial1/Subject5Activity11Trial1.csv . Shape : (1092,43)
# path : Subject5/Activity11/Trial2/Subject5Activity11Trial2.csv . Shape : (1088,43)
# path : Subject5/Activity11/Trial3/Subject5Activity11Trial3.csv . Shape : (1065,43)
# path : Subject6/Activity1/Trial1/Subject6Activity1Trial1.csv . Shape : (150,43)
# path : Subject6/Activity1/Trial2/Subject6Activity1Trial2.csv . Shape : (149,43)
# path : Subject6/Activity1/Trial3/Subject6Activity1Trial3.csv . Shape : (150,43)
# path : Subject6/Activity2/Trial1/Subject6Activity2Trial1.csv . Shape : (149,43)
# path : Subject6/Activity2/Trial2/Subject6Activity2Trial2.csv . Shape : (150,43)
# path : Subject6/Activity2/Trial3/Subject6Activity2Trial3.csv . Shape : (149,43)
# path : Subject6/Activity3/Trial1/Subject6Activity3Trial1.csv . Shape : (150,43)
# path : Subject6/Activity3/Trial2/Subject6Activity3Trial2.csv . Shape : (150,43)
# path : Subject6/Activity3/Trial3/Subject6Activity3Trial3.csv . Shape : (150,43)
# path : Subject6/Activity4/Trial1/Subject6Activity4Trial1.csv . Shape : (150,43)
# path : Subject6/Activity4/Trial2/Subject6Activity4Trial2.csv . Shape : (150,43)
# path : Subject6/Activity4/Trial3/Subject6Activity4Trial3.csv . Shape : (150,43)
# path : Subject6/Activity5/Trial1/Subject6Activity5Trial1.csv . Shape : (150,43)
# path : Subject6/Activity5/Trial2/Subject6Activity5Trial2.csv . Shape : (149,43)
# path : Subject6/Activity5/Trial3/Subject6Activity5Trial3.csv . Shape : (150,43)
# path : Subject6/Activity6/Trial1/Subject6Activity6Trial1.csv . Shape : (899,43)
# path : Subject6/Activity6/Trial2/Subject6Activity6Trial2.csv . Shape : (899,43)
# path : Subject6/Activity6/Trial3/Subject6Activity6Trial3.csv . Shape : (898,43)
# path : Subject6/Activity7/Trial1/Subject6Activity7Trial1.csv . Shape : (875,43)
# path : Subject6/Activity7/Trial2/Subject6Activity7Trial2.csv . Shape : (870,43)
# path : Subject6/Activity7/Trial3/Subject6Activity7Trial3.csv . Shape : (875,43)
# path : Subject6/Activity8/Trial1/Subject6Activity8Trial1.csv . Shape : (866,43)
# path : Subject6/Activity8/Trial2/Subject6Activity8Trial2.csv . Shape : (858,43)
# path : Subject6/Activity8/Trial3/Subject6Activity8Trial3.csv . Shape : (863,43)
# path : Subject6/Activity9/Trial1/Subject6Activity9Trial1.csv . Shape : (146,43)
# path : Subject6/Activity9/Trial2/Subject6Activity9Trial2.csv . Shape : (141,43)
# path : Subject6/Activity9/Trial3/Subject6Activity9Trial3.csv . Shape : (146,43)
# path : Subject6/Activity10/Trial1/Subject6Activity10Trial1.csv . Shape : (440,43)
# path : Subject6/Activity10/Trial2/Subject6Activity10Trial2.csv . Shape : (434,43)
# path : Subject6/Activity10/Trial3/Subject6Activity10Trial3.csv . Shape : (441,43)
# path : Subject6/Activity11/Trial1/Subject6Activity11Trial1.csv . Shape : (879,43)
# path : Subject6/Activity11/Trial2/Subject6Activity11Trial2.csv . Shape : (888,43)
# path : Subject6/Activity11/Trial3/Subject6Activity11Trial3.csv . Shape : (893,43)
# path : Subject7/Activity1/Trial1/Subject7Activity1Trial1.csv . Shape : (184,43)
# path : Subject7/Activity1/Trial2/Subject7Activity1Trial2.csv . Shape : (191,43)
# path : Subject7/Activity1/Trial3/Subject7Activity1Trial3.csv . Shape : (189,43)
# path : Subject7/Activity2/Trial1/Subject7Activity2Trial1.csv . Shape : (188,43)
# path : Subject7/Activity2/Trial2/Subject7Activity2Trial2.csv . Shape : (183,43)
# path : Subject7/Activity2/Trial3/Subject7Activity2Trial3.csv . Shape : (186,43)
# path : Subject7/Activity3/Trial1/Subject7Activity3Trial1.csv . Shape : (191,43)
# path : Subject7/Activity3/Trial2/Subject7Activity3Trial2.csv . Shape : (184,43)
# path : Subject7/Activity3/Trial3/Subject7Activity3Trial3.csv . Shape : (182,43)
# path : Subject7/Activity4/Trial1/Subject7Activity4Trial1.csv . Shape : (190,43)
# path : Subject7/Activity4/Trial2/Subject7Activity4Trial2.csv . Shape : (187,43)
# path : Subject7/Activity4/Trial3/Subject7Activity4Trial3.csv . Shape : (188,43)
# path : Subject7/Activity5/Trial1/Subject7Activity5Trial1.csv . Shape : (187,43)
# path : Subject7/Activity5/Trial2/Subject7Activity5Trial2.csv . Shape : (184,43)
# path : Subject7/Activity5/Trial3/Subject7Activity5Trial3.csv . Shape : (188,43)
# path : Subject7/Activity6/Trial1/Subject7Activity6Trial1.csv . Shape : (1121,43)
# path : Subject7/Activity6/Trial2/Subject7Activity6Trial2.csv . Shape : (1129,43)
# path : Subject7/Activity6/Trial3/Subject7Activity6Trial3.csv . Shape : (1116,43)
# path : Subject7/Activity7/Trial1/Subject7Activity7Trial1.csv . Shape : (1083,43)
# path : Subject7/Activity7/Trial2/Subject7Activity7Trial2.csv . Shape : (1077,43)
# path : Subject7/Activity7/Trial3/Subject7Activity7Trial3.csv . Shape : (1105,43)
# path : Subject7/Activity8/Trial1/Subject7Activity8Trial1.csv . Shape : (1088,43)
# path : Subject7/Activity8/Trial2/Subject7Activity8Trial2.csv . Shape : (1050,43)
# path : Subject7/Activity8/Trial3/Subject7Activity8Trial3.csv . Shape : (1063,43)
# path : Subject7/Activity9/Trial1/Subject7Activity9Trial1.csv . Shape : (189,43)
# path : Subject7/Activity9/Trial2/Subject7Activity9Trial2.csv . Shape : (185,43)
# path : Subject7/Activity9/Trial3/Subject7Activity9Trial3.csv . Shape : (192,43)
# path : Subject7/Activity10/Trial1/Subject7Activity10Trial1.csv . Shape : (573,43)
# path : Subject7/Activity10/Trial2/Subject7Activity10Trial2.csv . Shape : (562,43)
# path : Subject7/Activity10/Trial3/Subject7Activity10Trial3.csv . Shape : (566,43)
# path : Subject7/Activity11/Trial1/Subject7Activity11Trial1.csv . Shape : (1120,43)
# path : Subject7/Activity11/Trial2/Subject7Activity11Trial2.csv . Shape : (1047,43)
# path : Subject7/Activity11/Trial3/Subject7Activity11Trial3.csv . Shape : (1052,43)
# path : Subject8/Activity1/Trial1/Subject8Activity1Trial1.csv . Shape : (187,43)
# path : Subject8/Activity1/Trial2/Subject8Activity1Trial2.csv . Shape : (186,43)
# path : Subject8/Activity1/Trial3/Subject8Activity1Trial3.csv . Shape : (189,43)
# path : Subject8/Activity2/Trial1/Subject8Activity2Trial1.csv . Shape : (190,43)
# path : Subject8/Activity2/Trial2/Subject8Activity2Trial2.csv . Shape : (189,43)
# path : Subject8/Activity2/Trial3/Subject8Activity2Trial3.csv . Shape : (189,43)
# path : Subject8/Activity3/Trial1/Subject8Activity3Trial1.csv . Shape : (182,43)
# path : Subject8/Activity3/Trial2/Subject8Activity3Trial2.csv . Shape : (177,43)
# path : Subject8/Activity3/Trial3/Subject8Activity3Trial3.csv . Shape : (178,43)
# path : Subject8/Activity4/Trial1/Subject8Activity4Trial1.csv . Shape : (183,43)
# path : Subject8/Activity4/Trial2/Subject8Activity4Trial2.csv . Shape : (178,43)
# path : Subject8/Activity4/Trial3/Subject8Activity4Trial3.csv . Shape : (183,43)
# path : Subject8/Activity5/Trial1/Subject8Activity5Trial1.csv . Shape : (190,43)
# path : Subject8/Activity5/Trial2/Subject8Activity5Trial2.csv . Shape : (173,43)
# path : Subject8/Activity5/Trial3/Subject8Activity5Trial3.csv . Shape : (180,43)
# path : Subject8/Activity6/Trial1/Subject8Activity6Trial1.csv . Shape : (1046,43)
# path : Subject8/Activity6/Trial2/Subject8Activity6Trial2.csv . Shape : (1061,43)
# path : Subject8/Activity6/Trial3/Subject8Activity6Trial3.csv . Shape : (1040,43)
# path : Subject8/Activity7/Trial1/Subject8Activity7Trial1.csv . Shape : (1073,43)
# path : Subject8/Activity7/Trial2/Subject8Activity7Trial2.csv . Shape : (1084,43)
# path : Subject8/Activity7/Trial3/Subject8Activity7Trial3.csv . Shape : (1075,43)
# path : Subject8/Activity8/Trial1/Subject8Activity8Trial1.csv . Shape : (1066,43)
# path : Subject8/Activity8/Trial2/Subject8Activity8Trial2.csv . Shape : (1065,43)
# path : Subject8/Activity8/Trial3/Subject8Activity8Trial3.csv . Shape : (1093,43)
# path : Subject8/Activity9/Trial1/Subject8Activity9Trial1.csv . Shape : (169,43)
# path : Subject8/Activity9/Trial2/Subject8Activity9Trial2.csv . Shape : (185,43)
# path : Subject8/Activity9/Trial3/Subject8Activity9Trial3.csv . Shape : (181,43)
# path : Subject8/Activity10/Trial1/Subject8Activity10Trial1.csv . Shape : (543,43)
# path : Subject8/Activity10/Trial2/Subject8Activity10Trial2.csv . Shape : (546,43)
# path : Subject8/Activity10/Trial3/Subject8Activity10Trial3.csv . Shape : (550,43)
# path : Subject8/Activity11/Trial1/Subject8Activity11Trial1.csv . Shape : (1079,43)
# ----------------------------NULL---------------------------------
# ----------------------------NULL---------------------------------
# path : Subject9/Activity1/Trial1/Subject9Activity1Trial1.csv . Shape : (181,43)
# path : Subject9/Activity1/Trial2/Subject9Activity1Trial2.csv . Shape : (180,43)
# path : Subject9/Activity1/Trial3/Subject9Activity1Trial3.csv . Shape : (179,43)
# path : Subject9/Activity2/Trial1/Subject9Activity2Trial1.csv . Shape : (177,43)
# path : Subject9/Activity2/Trial2/Subject9Activity2Trial2.csv . Shape : (177,43)
# path : Subject9/Activity2/Trial3/Subject9Activity2Trial3.csv . Shape : (181,43)
# path : Subject9/Activity3/Trial1/Subject9Activity3Trial1.csv . Shape : (176,43)
# path : Subject9/Activity3/Trial2/Subject9Activity3Trial2.csv . Shape : (176,43)
# path : Subject9/Activity3/Trial3/Subject9Activity3Trial3.csv . Shape : (181,43)
# path : Subject9/Activity4/Trial1/Subject9Activity4Trial1.csv . Shape : (178,43)
# path : Subject9/Activity4/Trial2/Subject9Activity4Trial2.csv . Shape : (176,43)
# path : Subject9/Activity4/Trial3/Subject9Activity4Trial3.csv . Shape : (168,43)
# path : Subject9/Activity5/Trial1/Subject9Activity5Trial1.csv . Shape : (175,43)
# path : Subject9/Activity5/Trial2/Subject9Activity5Trial2.csv . Shape : (172,43)
# path : Subject9/Activity5/Trial3/Subject9Activity5Trial3.csv . Shape : (180,43)
# path : Subject9/Activity6/Trial1/Subject9Activity6Trial1.csv . Shape : (1074,43)
# path : Subject9/Activity6/Trial2/Subject9Activity6Trial2.csv . Shape : (1094,43)
# path : Subject9/Activity6/Trial3/Subject9Activity6Trial3.csv . Shape : (1055,43)
# path : Subject9/Activity7/Trial1/Subject9Activity7Trial1.csv . Shape : (1093,43)
# path : Subject9/Activity7/Trial2/Subject9Activity7Trial2.csv . Shape : (1074,43)
# path : Subject9/Activity7/Trial3/Subject9Activity7Trial3.csv . Shape : (1037,43)
# path : Subject9/Activity8/Trial1/Subject9Activity8Trial1.csv . Shape : (1069,43)
# path : Subject9/Activity8/Trial2/Subject9Activity8Trial2.csv . Shape : (1097,43)
# path : Subject9/Activity8/Trial3/Subject9Activity8Trial3.csv . Shape : (1069,43)
# path : Subject9/Activity9/Trial1/Subject9Activity9Trial1.csv . Shape : (185,43)
# path : Subject9/Activity9/Trial2/Subject9Activity9Trial2.csv . Shape : (181,43)
# path : Subject9/Activity9/Trial3/Subject9Activity9Trial3.csv . Shape : (178,43)
# path : Subject9/Activity10/Trial1/Subject9Activity10Trial1.csv . Shape : (557,43)
# path : Subject9/Activity10/Trial2/Subject9Activity10Trial2.csv . Shape : (537,43)
# path : Subject9/Activity10/Trial3/Subject9Activity10Trial3.csv . Shape : (554,43)
# path : Subject9/Activity11/Trial1/Subject9Activity11Trial1.csv . Shape : (1094,43)
# path : Subject9/Activity11/Trial2/Subject9Activity11Trial2.csv . Shape : (1098,43)
# path : Subject9/Activity11/Trial3/Subject9Activity11Trial3.csv . Shape : (1113,43)
# path : Subject10/Activity1/Trial1/Subject10Activity1Trial1.csv . Shape : (178,43)
# path : Subject10/Activity1/Trial2/Subject10Activity1Trial2.csv . Shape : (175,43)
# path : Subject10/Activity1/Trial3/Subject10Activity1Trial3.csv . Shape : (177,43)
# path : Subject10/Activity2/Trial1/Subject10Activity2Trial1.csv . Shape : (172,43)
# path : Subject10/Activity2/Trial2/Subject10Activity2Trial2.csv . Shape : (180,43)
# path : Subject10/Activity2/Trial3/Subject10Activity2Trial3.csv . Shape : (175,43)
# path : Subject10/Activity3/Trial1/Subject10Activity3Trial1.csv . Shape : (174,43)
# path : Subject10/Activity3/Trial2/Subject10Activity3Trial2.csv . Shape : (180,43)
# path : Subject10/Activity3/Trial3/Subject10Activity3Trial3.csv . Shape : (184,43)
# path : Subject10/Activity4/Trial1/Subject10Activity4Trial1.csv . Shape : (185,43)
# path : Subject10/Activity4/Trial2/Subject10Activity4Trial2.csv . Shape : (186,43)
# path : Subject10/Activity4/Trial3/Subject10Activity4Trial3.csv . Shape : (188,43)
# path : Subject10/Activity5/Trial1/Subject10Activity5Trial1.csv . Shape : (184,43)
# path : Subject10/Activity5/Trial2/Subject10Activity5Trial2.csv . Shape : (185,43)
# path : Subject10/Activity5/Trial3/Subject10Activity5Trial3.csv . Shape : (188,43)
# path : Subject10/Activity6/Trial1/Subject10Activity6Trial1.csv . Shape : (1127,43)
# path : Subject10/Activity6/Trial2/Subject10Activity6Trial2.csv . Shape : (1119,43)
# path : Subject10/Activity6/Trial3/Subject10Activity6Trial3.csv . Shape : (1129,43)
# path : Subject10/Activity7/Trial1/Subject10Activity7Trial1.csv . Shape : (1055,43)
# path : Subject10/Activity7/Trial2/Subject10Activity7Trial2.csv . Shape : (1038,43)
# path : Subject10/Activity7/Trial3/Subject10Activity7Trial3.csv . Shape : (1044,43)
# path : Subject10/Activity8/Trial1/Subject10Activity8Trial1.csv . Shape : (1023,43)
# path : Subject10/Activity8/Trial2/Subject10Activity8Trial2.csv . Shape : (1020,43)
# path : Subject10/Activity8/Trial3/Subject10Activity8Trial3.csv . Shape : (1050,43)
# path : Subject10/Activity9/Trial1/Subject10Activity9Trial1.csv . Shape : (162,43)
# path : Subject10/Activity9/Trial2/Subject10Activity9Trial2.csv . Shape : (168,43)
# path : Subject10/Activity9/Trial3/Subject10Activity9Trial3.csv . Shape : (168,43)
# path : Subject10/Activity10/Trial1/Subject10Activity10Trial1.csv . Shape : (528,43)
# path : Subject10/Activity10/Trial2/Subject10Activity10Trial2.csv . Shape : (528,43)
# path : Subject10/Activity10/Trial3/Subject10Activity10Trial3.csv . Shape : (536,43)
# path : Subject10/Activity11/Trial1/Subject10Activity11Trial1.csv . Shape : (1055,43)
# path : Subject10/Activity11/Trial2/Subject10Activity11Trial2.csv . Shape : (1071,43)
# path : Subject10/Activity11/Trial3/Subject10Activity11Trial3.csv . Shape : (1069,43)
# path : Subject11/Activity1/Trial1/Subject11Activity1Trial1.csv . Shape : (177,43)
# path : Subject11/Activity1/Trial2/Subject11Activity1Trial2.csv . Shape : (179,43)
# path : Subject11/Activity1/Trial3/Subject11Activity1Trial3.csv . Shape : (170,43)
# path : Subject11/Activity2/Trial1/Subject11Activity2Trial1.csv . Shape : (188,43)
# path : Subject11/Activity2/Trial2/Subject11Activity2Trial2.csv . Shape : (185,43)
# path : Subject11/Activity2/Trial3/Subject11Activity2Trial3.csv . Shape : (186,43)
# path : Subject11/Activity3/Trial1/Subject11Activity3Trial1.csv . Shape : (190,43)
# path : Subject11/Activity3/Trial2/Subject11Activity3Trial2.csv . Shape : (187,43)
# path : Subject11/Activity3/Trial3/Subject11Activity3Trial3.csv . Shape : (189,43)
# path : Subject11/Activity4/Trial1/Subject11Activity4Trial1.csv . Shape : (188,43)
# path : Subject11/Activity4/Trial2/Subject11Activity4Trial2.csv . Shape : (189,43)
# path : Subject11/Activity4/Trial3/Subject11Activity4Trial3.csv . Shape : (185,43)
# path : Subject11/Activity5/Trial1/Subject11Activity5Trial1.csv . Shape : (189,43)
# path : Subject11/Activity5/Trial2/Subject11Activity5Trial2.csv . Shape : (186,43)
# path : Subject11/Activity5/Trial3/Subject11Activity5Trial3.csv . Shape : (187,43)
# path : Subject11/Activity6/Trial1/Subject11Activity6Trial1.csv . Shape : (1138,43)
# path : Subject11/Activity6/Trial2/Subject11Activity6Trial2.csv . Shape : (1141,43)
# path : Subject11/Activity6/Trial3/Subject11Activity6Trial3.csv . Shape : (1144,43)
# path : Subject11/Activity7/Trial1/Subject11Activity7Trial1.csv . Shape : (1110,43)
# path : Subject11/Activity7/Trial2/Subject11Activity7Trial2.csv . Shape : (1071,43)
# path : Subject11/Activity7/Trial3/Subject11Activity7Trial3.csv . Shape : (1059,43)
# path : Subject11/Activity8/Trial1/Subject11Activity8Trial1.csv . Shape : (1039,43)
# path : Subject11/Activity8/Trial2/Subject11Activity8Trial2.csv . Shape : (1097,43)
# path : Subject11/Activity8/Trial3/Subject11Activity8Trial3.csv . Shape : (1071,43)
# path : Subject11/Activity9/Trial1/Subject11Activity9Trial1.csv . Shape : (180,43)
# path : Subject11/Activity9/Trial2/Subject11Activity9Trial2.csv . Shape : (186,43)
# path : Subject11/Activity9/Trial3/Subject11Activity9Trial3.csv . Shape : (182,43)
# path : Subject11/Activity10/Trial1/Subject11Activity10Trial1.csv . Shape : (554,43)
# path : Subject11/Activity10/Trial2/Subject11Activity10Trial2.csv . Shape : (554,43)
# path : Subject11/Activity10/Trial3/Subject11Activity10Trial3.csv . Shape : (565,43)
# path : Subject11/Activity11/Trial1/Subject11Activity11Trial1.csv . Shape : (1084,43)
# path : Subject11/Activity11/Trial2/Subject11Activity11Trial2.csv . Shape : (1091,43)
# path : Subject11/Activity11/Trial3/Subject11Activity11Trial3.csv . Shape : (1085,43)
# path : Subject12/Activity1/Trial1/Subject12Activity1Trial1.csv . Shape : (193,43)
# path : Subject12/Activity1/Trial2/Subject12Activity1Trial2.csv . Shape : (193,43)
# path : Subject12/Activity1/Trial3/Subject12Activity1Trial3.csv . Shape : (191,43)
# path : Subject12/Activity2/Trial1/Subject12Activity2Trial1.csv . Shape : (195,43)
# path : Subject12/Activity2/Trial2/Subject12Activity2Trial2.csv . Shape : (196,43)
# path : Subject12/Activity2/Trial3/Subject12Activity2Trial3.csv . Shape : (200,43)
# path : Subject12/Activity3/Trial1/Subject12Activity3Trial1.csv . Shape : (193,43)
# path : Subject12/Activity3/Trial2/Subject12Activity3Trial2.csv . Shape : (192,43)
# path : Subject12/Activity3/Trial3/Subject12Activity3Trial3.csv . Shape : (192,43)
# path : Subject12/Activity4/Trial1/Subject12Activity4Trial1.csv . Shape : (192,43)
# path : Subject12/Activity4/Trial2/Subject12Activity4Trial2.csv . Shape : (188,43)
# path : Subject12/Activity4/Trial3/Subject12Activity4Trial3.csv . Shape : (189,43)
# path : Subject12/Activity5/Trial1/Subject12Activity5Trial1.csv . Shape : (191,43)
# path : Subject12/Activity5/Trial2/Subject12Activity5Trial2.csv . Shape : (190,43)
# path : Subject12/Activity5/Trial3/Subject12Activity5Trial3.csv . Shape : (192,43)
# path : Subject12/Activity6/Trial1/Subject12Activity6Trial1.csv . Shape : (1145,43)
# path : Subject12/Activity6/Trial2/Subject12Activity6Trial2.csv . Shape : (1134,43)
# path : Subject12/Activity6/Trial3/Subject12Activity6Trial3.csv . Shape : (1130,43)
# path : Subject12/Activity7/Trial1/Subject12Activity7Trial1.csv . Shape : (1111,43)
# path : Subject12/Activity7/Trial2/Subject12Activity7Trial2.csv . Shape : (1123,43)
# path : Subject12/Activity7/Trial3/Subject12Activity7Trial3.csv . Shape : (1119,43)
# path : Subject12/Activity8/Trial1/Subject12Activity8Trial1.csv . Shape : (1069,43)
# path : Subject12/Activity8/Trial2/Subject12Activity8Trial2.csv . Shape : (1106,43)
# path : Subject12/Activity8/Trial3/Subject12Activity8Trial3.csv . Shape : (1132,43)
# path : Subject12/Activity9/Trial1/Subject12Activity9Trial1.csv . Shape : (187,43)
# path : Subject12/Activity9/Trial2/Subject12Activity9Trial2.csv . Shape : (186,43)
# path : Subject12/Activity9/Trial3/Subject12Activity9Trial3.csv . Shape : (183,43)
# path : Subject12/Activity10/Trial1/Subject12Activity10Trial1.csv . Shape : (563,43)
# path : Subject12/Activity10/Trial2/Subject12Activity10Trial2.csv . Shape : (569,43)
# path : Subject12/Activity10/Trial3/Subject12Activity10Trial3.csv . Shape : (555,43)
# path : Subject12/Activity11/Trial1/Subject12Activity11Trial1.csv . Shape : (1130,43)
# path : Subject12/Activity11/Trial2/Subject12Activity11Trial2.csv . Shape : (1115,43)
# path : Subject12/Activity11/Trial3/Subject12Activity11Trial3.csv . Shape : (1137,43)
# path : Subject13/Activity1/Trial1/Subject13Activity1Trial1.csv . Shape : (176,43)
# path : Subject13/Activity1/Trial2/Subject13Activity1Trial2.csv . Shape : (186,43)
# path : Subject13/Activity1/Trial3/Subject13Activity1Trial3.csv . Shape : (184,43)
# path : Subject13/Activity2/Trial1/Subject13Activity2Trial1.csv . Shape : (181,43)
# path : Subject13/Activity2/Trial2/Subject13Activity2Trial2.csv . Shape : (178,43)
# path : Subject13/Activity2/Trial3/Subject13Activity2Trial3.csv . Shape : (185,43)
# path : Subject13/Activity3/Trial1/Subject13Activity3Trial1.csv . Shape : (184,43)
# path : Subject13/Activity3/Trial2/Subject13Activity3Trial2.csv . Shape : (175,43)
# path : Subject13/Activity3/Trial3/Subject13Activity3Trial3.csv . Shape : (184,43)
# path : Subject13/Activity4/Trial1/Subject13Activity4Trial1.csv . Shape : (183,43)
# path : Subject13/Activity4/Trial2/Subject13Activity4Trial2.csv . Shape : (168,43)
# path : Subject13/Activity4/Trial3/Subject13Activity4Trial3.csv . Shape : (185,43)
# path : Subject13/Activity5/Trial1/Subject13Activity5Trial1.csv . Shape : (175,43)
# path : Subject13/Activity5/Trial2/Subject13Activity5Trial2.csv . Shape : (170,43)
# path : Subject13/Activity5/Trial3/Subject13Activity5Trial3.csv . Shape : (178,43)
# path : Subject13/Activity6/Trial1/Subject13Activity6Trial1.csv . Shape : (1043,43)
# path : Subject13/Activity6/Trial2/Subject13Activity6Trial2.csv . Shape : (1020,43)
# path : Subject13/Activity6/Trial3/Subject13Activity6Trial3.csv . Shape : (965,43)
# path : Subject13/Activity7/Trial1/Subject13Activity7Trial1.csv . Shape : (1133,43)
# path : Subject13/Activity7/Trial2/Subject13Activity7Trial2.csv . Shape : (1127,43)
# path : Subject13/Activity7/Trial3/Subject13Activity7Trial3.csv . Shape : (1100,43)
# path : Subject13/Activity8/Trial1/Subject13Activity8Trial1.csv . Shape : (1090,43)
# path : Subject13/Activity8/Trial2/Subject13Activity8Trial2.csv . Shape : (1086,43)
# path : Subject13/Activity8/Trial3/Subject13Activity8Trial3.csv . Shape : (1073,43)
# path : Subject13/Activity9/Trial1/Subject13Activity9Trial1.csv . Shape : (177,43)
# path : Subject13/Activity9/Trial2/Subject13Activity9Trial2.csv . Shape : (178,43)
# path : Subject13/Activity9/Trial3/Subject13Activity9Trial3.csv . Shape : (180,43)
# path : Subject13/Activity10/Trial1/Subject13Activity10Trial1.csv . Shape : (506,43)
# path : Subject13/Activity10/Trial2/Subject13Activity10Trial2.csv . Shape : (504,43)
# path : Subject13/Activity10/Trial3/Subject13Activity10Trial3.csv . Shape : (525,43)
# path : Subject13/Activity11/Trial1/Subject13Activity11Trial1.csv . Shape : (1040,43)
# path : Subject13/Activity11/Trial2/Subject13Activity11Trial2.csv . Shape : (1038,43)
# path : Subject13/Activity11/Trial3/Subject13Activity11Trial3.csv . Shape : (1025,43)
# path : Subject14/Activity1/Trial1/Subject14Activity1Trial1.csv . Shape : (185,43)
# path : Subject14/Activity1/Trial2/Subject14Activity1Trial2.csv . Shape : (183,43)
# path : Subject14/Activity1/Trial3/Subject14Activity1Trial3.csv . Shape : (183,43)
# path : Subject14/Activity2/Trial1/Subject14Activity2Trial1.csv . Shape : (178,43)
# path : Subject14/Activity2/Trial2/Subject14Activity2Trial2.csv . Shape : (169,43)
# path : Subject14/Activity2/Trial3/Subject14Activity2Trial3.csv . Shape : (169,43)
# path : Subject14/Activity3/Trial1/Subject14Activity3Trial1.csv . Shape : (181,43)
# path : Subject14/Activity3/Trial2/Subject14Activity3Trial2.csv . Shape : (168,43)
# path : Subject14/Activity3/Trial3/Subject14Activity3Trial3.csv . Shape : (183,43)
# path : Subject14/Activity4/Trial1/Subject14Activity4Trial1.csv . Shape : (177,43)
# path : Subject14/Activity4/Trial2/Subject14Activity4Trial2.csv . Shape : (177,43)
# path : Subject14/Activity4/Trial3/Subject14Activity4Trial3.csv . Shape : (182,43)
# path : Subject14/Activity5/Trial1/Subject14Activity5Trial1.csv . Shape : (181,43)
# path : Subject14/Activity5/Trial2/Subject14Activity5Trial2.csv . Shape : (184,43)
# path : Subject14/Activity5/Trial3/Subject14Activity5Trial3.csv . Shape : (179,43)
# path : Subject14/Activity6/Trial1/Subject14Activity6Trial1.csv . Shape : (1036,43)
# path : Subject14/Activity6/Trial2/Subject14Activity6Trial2.csv . Shape : (999,43)
# path : Subject14/Activity6/Trial3/Subject14Activity6Trial3.csv . Shape : (1078,43)
# path : Subject14/Activity7/Trial1/Subject14Activity7Trial1.csv . Shape : (1108,43)
# path : Subject14/Activity7/Trial2/Subject14Activity7Trial2.csv . Shape : (1055,43)
# path : Subject14/Activity7/Trial3/Subject14Activity7Trial3.csv . Shape : (1087,43)
# path : Subject14/Activity8/Trial1/Subject14Activity8Trial1.csv . Shape : (1078,43)
# path : Subject14/Activity8/Trial2/Subject14Activity8Trial2.csv . Shape : (1043,43)
# path : Subject14/Activity8/Trial3/Subject14Activity8Trial3.csv . Shape : (1069,43)
# path : Subject14/Activity9/Trial1/Subject14Activity9Trial1.csv . Shape : (162,43)
# path : Subject14/Activity9/Trial2/Subject14Activity9Trial2.csv . Shape : (179,43)
# path : Subject14/Activity9/Trial3/Subject14Activity9Trial3.csv . Shape : (173,43)
# path : Subject14/Activity10/Trial1/Subject14Activity10Trial1.csv . Shape : (507,43)
# path : Subject14/Activity10/Trial2/Subject14Activity10Trial2.csv . Shape : (504,43)
# path : Subject14/Activity10/Trial3/Subject14Activity10Trial3.csv . Shape : (518,43)
# path : Subject14/Activity11/Trial1/Subject14Activity11Trial1.csv . Shape : (1021,43)
# path : Subject14/Activity11/Trial2/Subject14Activity11Trial2.csv . Shape : (935,43)
# path : Subject14/Activity11/Trial3/Subject14Activity11Trial3.csv . Shape : (983,43)
# path : Subject15/Activity1/Trial1/Subject15Activity1Trial1.csv . Shape : (182,43)
# path : Subject15/Activity1/Trial2/Subject15Activity1Trial2.csv . Shape : (177,43)
# path : Subject15/Activity1/Trial3/Subject15Activity1Trial3.csv . Shape : (179,43)
# path : Subject15/Activity2/Trial1/Subject15Activity2Trial1.csv . Shape : (180,43)
# path : Subject15/Activity2/Trial2/Subject15Activity2Trial2.csv . Shape : (175,43)
# path : Subject15/Activity2/Trial3/Subject15Activity2Trial3.csv . Shape : (175,43)
# path : Subject15/Activity3/Trial1/Subject15Activity3Trial1.csv . Shape : (184,43)
# path : Subject15/Activity3/Trial2/Subject15Activity3Trial2.csv . Shape : (180,43)
# path : Subject15/Activity3/Trial3/Subject15Activity3Trial3.csv . Shape : (187,43)
# path : Subject15/Activity4/Trial1/Subject15Activity4Trial1.csv . Shape : (184,43)
# path : Subject15/Activity4/Trial2/Subject15Activity4Trial2.csv . Shape : (174,43)
# path : Subject15/Activity4/Trial3/Subject15Activity4Trial3.csv . Shape : (176,43)
# path : Subject15/Activity5/Trial1/Subject15Activity5Trial1.csv . Shape : (181,43)
# path : Subject15/Activity5/Trial2/Subject15Activity5Trial2.csv . Shape : (177,43)
# path : Subject15/Activity5/Trial3/Subject15Activity5Trial3.csv . Shape : (175,43)
# path : Subject15/Activity6/Trial1/Subject15Activity6Trial1.csv . Shape : (1069,43)
# path : Subject15/Activity6/Trial2/Subject15Activity6Trial2.csv . Shape : (1073,43)
# path : Subject15/Activity6/Trial3/Subject15Activity6Trial3.csv . Shape : (1065,43)
# path : Subject15/Activity7/Trial1/Subject15Activity7Trial1.csv . Shape : (1041,43)
# path : Subject15/Activity7/Trial2/Subject15Activity7Trial2.csv . Shape : (1040,43)
# path : Subject15/Activity7/Trial3/Subject15Activity7Trial3.csv . Shape : (1060,43)
# path : Subject15/Activity8/Trial1/Subject15Activity8Trial1.csv . Shape : (1057,43)
# path : Subject15/Activity8/Trial2/Subject15Activity8Trial2.csv . Shape : (1083,43)
# path : Subject15/Activity8/Trial3/Subject15Activity8Trial3.csv . Shape : (1051,43)
# path : Subject15/Activity9/Trial1/Subject15Activity9Trial1.csv . Shape : (170,43)
# path : Subject15/Activity9/Trial2/Subject15Activity9Trial2.csv . Shape : (172,43)
# path : Subject15/Activity9/Trial3/Subject15Activity9Trial3.csv . Shape : (175,43)
# path : Subject15/Activity10/Trial1/Subject15Activity10Trial1.csv . Shape : (492,43)
# path : Subject15/Activity10/Trial2/Subject15Activity10Trial2.csv . Shape : (498,43)
# path : Subject15/Activity10/Trial3/Subject15Activity10Trial3.csv . Shape : (507,43)
# path : Subject15/Activity11/Trial1/Subject15Activity11Trial1.csv . Shape : (1010,43)
# path : Subject15/Activity11/Trial2/Subject15Activity11Trial2.csv . Shape : (1005,43)
# path : Subject15/Activity11/Trial3/Subject15Activity11Trial3.csv . Shape : (1111,43)
# path : Subject16/Activity1/Trial1/Subject16Activity1Trial1.csv . Shape : (188,43)
# path : Subject16/Activity1/Trial2/Subject16Activity1Trial2.csv . Shape : (174,43)
# path : Subject16/Activity1/Trial3/Subject16Activity1Trial3.csv . Shape : (177,43)
# path : Subject16/Activity2/Trial1/Subject16Activity2Trial1.csv . Shape : (171,43)
# path : Subject16/Activity2/Trial2/Subject16Activity2Trial2.csv . Shape : (176,43)
# path : Subject16/Activity2/Trial3/Subject16Activity2Trial3.csv . Shape : (171,43)
# path : Subject16/Activity3/Trial1/Subject16Activity3Trial1.csv . Shape : (169,43)
# path : Subject16/Activity3/Trial2/Subject16Activity3Trial2.csv . Shape : (177,43)
# path : Subject16/Activity3/Trial3/Subject16Activity3Trial3.csv . Shape : (172,43)
# path : Subject16/Activity4/Trial1/Subject16Activity4Trial1.csv . Shape : (168,43)
# path : Subject16/Activity4/Trial2/Subject16Activity4Trial2.csv . Shape : (172,43)
# path : Subject16/Activity4/Trial3/Subject16Activity4Trial3.csv . Shape : (174,43)
# path : Subject16/Activity5/Trial1/Subject16Activity5Trial1.csv . Shape : (164,43)
# path : Subject16/Activity5/Trial2/Subject16Activity5Trial2.csv . Shape : (170,43)
# path : Subject16/Activity5/Trial3/Subject16Activity5Trial3.csv . Shape : (151,43)
# path : Subject16/Activity6/Trial1/Subject16Activity6Trial1.csv . Shape : (983,43)
# path : Subject16/Activity6/Trial2/Subject16Activity6Trial2.csv . Shape : (958,43)
# path : Subject16/Activity6/Trial3/Subject16Activity6Trial3.csv . Shape : (937,43)
# path : Subject16/Activity7/Trial1/Subject16Activity7Trial1.csv . Shape : (987,43)
# path : Subject16/Activity7/Trial2/Subject16Activity7Trial2.csv . Shape : (993,43)
# path : Subject16/Activity7/Trial3/Subject16Activity7Trial3.csv . Shape : (991,43)
# path : Subject16/Activity8/Trial1/Subject16Activity8Trial1.csv . Shape : (1005,43)
# path : Subject16/Activity8/Trial2/Subject16Activity8Trial2.csv . Shape : (978,43)
# path : Subject16/Activity8/Trial3/Subject16Activity8Trial3.csv . Shape : (977,43)
# path : Subject16/Activity9/Trial1/Subject16Activity9Trial1.csv . Shape : (158,43)
# path : Subject16/Activity9/Trial2/Subject16Activity9Trial2.csv . Shape : (149,43)
# path : Subject16/Activity9/Trial3/Subject16Activity9Trial3.csv . Shape : (141,43)
# path : Subject16/Activity10/Trial1/Subject16Activity10Trial1.csv . Shape : (482,43)
# path : Subject16/Activity10/Trial2/Subject16Activity10Trial2.csv . Shape : (485,43)
# path : Subject16/Activity10/Trial3/Subject16Activity10Trial3.csv . Shape : (496,43)
# path : Subject16/Activity11/Trial1/Subject16Activity11Trial1.csv . Shape : (960,43)
# path : Subject16/Activity11/Trial2/Subject16Activity11Trial2.csv . Shape : (988,43)
# path : Subject16/Activity11/Trial3/Subject16Activity11Trial3.csv . Shape : (925,43)
# path : Subject17/Activity1/Trial1/Subject17Activity1Trial1.csv . Shape : (168,43)
# path : Subject17/Activity1/Trial2/Subject17Activity1Trial2.csv . Shape : (177,43)
# path : Subject17/Activity1/Trial3/Subject17Activity1Trial3.csv . Shape : (169,43)
# path : Subject17/Activity2/Trial1/Subject17Activity2Trial1.csv . Shape : (182,43)
# path : Subject17/Activity2/Trial2/Subject17Activity2Trial2.csv . Shape : (184,43)
# path : Subject17/Activity2/Trial3/Subject17Activity2Trial3.csv . Shape : (185,43)
# path : Subject17/Activity3/Trial1/Subject17Activity3Trial1.csv . Shape : (186,43)
# path : Subject17/Activity3/Trial2/Subject17Activity3Trial2.csv . Shape : (184,43)
# path : Subject17/Activity3/Trial3/Subject17Activity3Trial3.csv . Shape : (184,43)
# path : Subject17/Activity4/Trial1/Subject17Activity4Trial1.csv . Shape : (188,43)
# path : Subject17/Activity4/Trial2/Subject17Activity4Trial2.csv . Shape : (185,43)
# path : Subject17/Activity4/Trial3/Subject17Activity4Trial3.csv . Shape : (176,43)
# path : Subject17/Activity5/Trial1/Subject17Activity5Trial1.csv . Shape : (182,43)
# path : Subject17/Activity5/Trial2/Subject17Activity5Trial2.csv . Shape : (180,43)
# path : Subject17/Activity5/Trial3/Subject17Activity5Trial3.csv . Shape : (177,43)
# path : Subject17/Activity6/Trial1/Subject17Activity6Trial1.csv . Shape : (1091,43)
# path : Subject17/Activity6/Trial2/Subject17Activity6Trial2.csv . Shape : (1085,43)
# path : Subject17/Activity6/Trial3/Subject17Activity6Trial3.csv . Shape : (1078,43)
# path : Subject17/Activity7/Trial1/Subject17Activity7Trial1.csv . Shape : (1018,43)
# path : Subject17/Activity7/Trial2/Subject17Activity7Trial2.csv . Shape : (996,43)
# path : Subject17/Activity7/Trial3/Subject17Activity7Trial3.csv . Shape : (1000,43)
# path : Subject17/Activity8/Trial1/Subject17Activity8Trial1.csv . Shape : (1043,43)
# path : Subject17/Activity8/Trial2/Subject17Activity8Trial2.csv . Shape : (1057,43)
# path : Subject17/Activity8/Trial3/Subject17Activity8Trial3.csv . Shape : (1061,43)
# path : Subject17/Activity9/Trial1/Subject17Activity9Trial1.csv . Shape : (182,43)
# path : Subject17/Activity9/Trial2/Subject17Activity9Trial2.csv . Shape : (179,43)
# path : Subject17/Activity9/Trial3/Subject17Activity9Trial3.csv . Shape : (176,43)
# path : Subject17/Activity10/Trial1/Subject17Activity10Trial1.csv . Shape : (544,43)
# path : Subject17/Activity10/Trial2/Subject17Activity10Trial2.csv . Shape : (523,43)
# path : Subject17/Activity10/Trial3/Subject17Activity10Trial3.csv . Shape : (532,43)
# path : Subject17/Activity11/Trial1/Subject17Activity11Trial1.csv . Shape : (1054,43)
# path : Subject17/Activity11/Trial2/Subject17Activity11Trial2.csv . Shape : (1049,43)
# path : Subject17/Activity11/Trial3/Subject17Activity11Trial3.csv . Shape : (1036,43)

# %%
SUB.to_csv(path_or_buf='Sensor + Image/sensor.csv', index = False)

# %%
times = SUB.iloc[:,0].values
labels = SUB.iloc[:,-1].values
Time_Label = pd.DataFrame(labels , index = times)
Time_Label
# Out:
#                              0
# 2018-07-04T12:04:17.738369   7
# 2018-07-04T12:04:17.790509   7
# 2018-07-04T12:04:17.836632   7
# 2018-07-04T12:04:17.885262   7
# 2018-07-04T12:04:17.945423   7
# ...                         ..
# 2018-07-12T12:18:28.783680  11
# 2018-07-12T12:18:28.832811  11
# 2018-07-12T12:18:28.892470  11
# 2018-07-12T12:18:29.025324  11
# 2018-07-12T12:18:29.070446  11
#
# [294678 rows x 1 columns]

# %% [markdown]
# ## Load image

# %%
def load_img(start_sub, end_sub ,start_act  , end_act ,  start_cam ,  end_cam , DesiredWidth = 64, DesiredHeight = 64 ):
    IMG = []
    count = 0
    name_img = []
    for sub_ in range(start_sub, end_sub+1):
        sub = 'Subject' + str(sub_)

        for act_ in range(start_act, end_act + 1) :
            act = 'Activity' + str(act_)

            for trial_ in range(1, 3 + 1):
                trial = 'Trial'+ str(trial_)
                if ( (sub_ == 8 and act_ == 11) and ( trial_ == 2 or trial_ == 3) ) :
                    print('----------------------------NULL---------------------------------')
                    continue 
                for cam_ in range(start_cam , end_cam + 1) :
                    cam = 'Camera'+ str(cam_)

                    with ZipFile( sub + '/' + act  + '/'+ trial +  '/' + sub + act  + trial + cam + '.zip', 'r') as zipObj:
                        zipObj.extractall('CAMERA/' + sub + act  + trial  + cam)

                    for root, dirnames, filenames in os.walk('CAMERA/' + sub + act + trial  +cam ):
                        for filename in filenames:
                            if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
                                filepath = os.path.join(root, filename)
                                count += 1 
                                if count % 5000 == 0 :
                                    print('{} : {} ' .format(filepath,count))
                                if filepath == 'CAMERA/Subject6Activity10Trial2Camera2/2018-07-06T12_03_04.483526.png' :
                                    print('----------------------------NO SHAPE---------------------------------')
                                    continue
                                elif len(filepath) > 70 :
                                    print(' {} : Invalid image'.format(filepath))
                                    continue 
                                name_img.append(filepath)
                                img = cv2.imread(filepath, 0) 
                                resized = ResizeImage(img, DesiredWidth, DesiredHeight)
                                IMG.append(resized)
                    shutil.rmtree('CAMERA/'+ sub + act + trial + cam)
    return IMG , name_img


def handle_name(path_name) :
    img_name = []
    for path in path_name :
        if len(path) == 68: 
            img_name.append(path[38:64])
        elif len(path) == 69 :
            img_name.append(path[39:65])
        else :
            img_name.append(path[40:66])
    handle = []
    for name in img_name :
        n1 = 13
        a1 = name.replace(name[n1],':')
        n2 = 16
        a2 = a1.replace(name[n2],':')
        handle.append(a2)
    return handle 


def ShowImage(ImageList, nRows = 1, nCols = 2, WidthSpace = 0.00, HeightSpace = 0.00):
    from matplotlib import pyplot as plt 
    import matplotlib.gridspec as gridspec
    gs = gridspec.GridSpec(nRows, nCols)     
    gs.update(wspace=WidthSpace, hspace=HeightSpace) # set the spacing between axes.
    plt.figure(figsize=(20,20))
    for i in range(len(ImageList)):
        ax1 = plt.subplot(gs[i])
        ax1.set_xticklabels([])
        ax1.set_yticklabels([])
        ax1.set_aspect('equal')
        plt.subplot(nRows, nCols,i+1)
        image = ImageList[i].copy()
        if (len(image.shape) < 3):
            plt.imshow(image, plt.cm.gray)
        else:
            plt.imshow(image)
        plt.title("Image " + str(i))
        plt.axis('off')
    plt.show()
    
    
def ResizeImage(IM, DesiredWidth, DesiredHeight):
    OrigWidth = float(IM.shape[1])
    OrigHeight = float(IM.shape[0])
    Width = DesiredWidth 
    Height = DesiredHeight

    if((Width == 0) & (Height == 0)):
        return IM
    
    if(Width == 0):
        Width = int((OrigWidth * Height)/OrigHeight)

    if(Height == 0):
        Height = int((OrigHeight * Width)/OrigWidth)

    dim = (Width, Height)
    resizedIM = cv2.resize(IM, dim, interpolation = cv2.INTER_NEAREST) 
    return resizedIM

# %%
start_sub = 1
end_sub  = 17
start_act = 1
end_act = 11
start_cam = 1 
end_cam = 1
DesiredWidth = 32
DesiredHeight = 32


img_1, path_1 = load_img(start_sub ,   end_sub,
             start_act , end_act  ,
             start_cam ,   end_cam , DesiredWidth ,  DesiredHeight )


name_1 = handle_name(path_1)
# Out:
# CAMERA/Subject1Activity6Trial2Camera1/2018-07-04T12_12_01.821800.png : 5000
# CAMERA/Subject1Activity8Trial1Camera1/2018-07-04T12_17_22.832033.png : 10000
# CAMERA/Subject1Activity11Trial1Camera1/2018-07-04T12_24_58.704636.png : 15000
# CAMERA/Subject2Activity4Trial3Camera1/2018-07-11T13_43_26.285138.png : 20000
# CAMERA/Subject2Activity7Trial2Camera1/2018-07-11T13_50_50.004135.png : 25000
# CAMERA/Subject2Activity9Trial1Camera1/2018-07-11T13_56_53.362931.png : 30000
# CAMERA/Subject3Activity1Trial2Camera1/2018-07-05T12_06_01.688633.png : 35000
# CAMERA/Subject3Activity6Trial3Camera1/2018-07-05T12_14_06.877929.png : 40000
# CAMERA/Subject3Activity8Trial1Camera1/2018-07-05T12_18_14.845539.png : 45000
# CAMERA/Subject3Activity11Trial1Camera1/2018-07-05T12_26_28.098231.png : 50000
# CAMERA/Subject4Activity5Trial2Camera1/2018-07-10T13_32_37.424598.png : 55000
# CAMERA/Subject4Activity7Trial2Camera1/2018-07-10T13_38_18.520676.png : 60000
# CAMERA/Subject4Activity9Trial1Camera1/2018-07-10T13_44_02.354607.png : 65000
# CAMERA/Subject4Activity11Trial3Camera1/2018-07-10T13_50_21.986107.png : 70000
# CAMERA/Subject5Activity6Trial2Camera1/2018-07-06T10_50_26.491048.png : 75000
# CAMERA/Subject5Activity8Trial1Camera1/2018-07-06T10_56_26.305351.png : 80000
# CAMERA/Subject5Activity10Trial3Camera1/2018-07-06T11_02_56.359605.png : 85000
# CAMERA/Subject6Activity4Trial1Camera1/2018-07-06T11_46_35.173055.png : 90000
# CAMERA/Subject6Activity7Trial2Camera1/2018-07-06T11_55_16.693749.png : 95000
# CAMERA/Subject6Activity10Trial2Camera1/2018-07-06T12_03_18.429171.png : 100000
# CAMERA/Subject7Activity4Trial1Camera1/2018-07-06T12_46_35.832517.png : 105000
# CAMERA/Subject7Activity7Trial1Camera1/2018-07-06T12_52_34.661140.png : 110000
# CAMERA/Subject7Activity8Trial3Camera1/2018-07-06T12_59_35.429935.png : 115000
# CAMERA/Subject7Activity11Trial2Camera1/2018-07-06T13_06_00.655565.png : 120000
# CAMERA/Subject8Activity6Trial1Camera1/2018-07-09T10_26_28.416737.png : 125000
# CAMERA/Subject8Activity7Trial3Camera1/2018-07-09T10_32_30.986440.png : 130000
# CAMERA/Subject8Activity10Trial2Camera1/2018-07-09T10_38_08.475093.png : 135000
# ----------------------------NULL---------------------------------
# ----------------------------NULL---------------------------------
# CAMERA/Subject9Activity6Trial1Camera1/2018-07-09T12_09_12.206066.png : 140000
# CAMERA/Subject9Activity7Trial3Camera1/2018-07-09T12_14_51.135300.png : 145000
# CAMERA/Subject9Activity10Trial1Camera1/2018-07-09T12_21_06.369443.png : 150000
# CAMERA/Subject10Activity1Trial2Camera1/2018-07-10T13_08_48.932891.png : 155000
# CAMERA/Subject10Activity6Trial3Camera1/2018-07-09T13_46_38.653642.png : 160000
# CAMERA/Subject10Activity8Trial2Camera1/2018-07-09T13_52_14.276074.png : 165000
# CAMERA/Subject10Activity11Trial1Camera1/2018-07-09T13_58_54.695451.png : 170000
# CAMERA/Subject11Activity5Trial3Camera1/2018-07-10T10_41_29.374829.png : 175000
# CAMERA/Subject11Activity7Trial2Camera1/2018-07-10T10_47_10.222770.png : 180000
# CAMERA/Subject11Activity9Trial1Camera1/2018-07-10T10_53_22.786831.png : 185000
# CAMERA/Subject11Activity11Trial3Camera1/2018-07-10T12_25_18.145061.png : 190000
# CAMERA/Subject12Activity6Trial2Camera1/2018-07-10T11_40_30.643143.png : 195000
# CAMERA/Subject12Activity7Trial3Camera1/2018-07-10T11_45_21.883728.png : 200000
# CAMERA/Subject12Activity10Trial2Camera1/2018-07-10T11_52_09.956692.png : 205000
# CAMERA/Subject13Activity2Trial3Camera1/2018-07-11T12_45_17.121661.png : 210000
# CAMERA/Subject13Activity7Trial1Camera1/2018-07-11T12_53_27.129188.png : 215000
# CAMERA/Subject13Activity8Trial2Camera1/2018-07-11T12_57_41.551308.png : 220000
# CAMERA/Subject13Activity11Trial2Camera1/2018-07-11T13_04_39.397232.png : 225000
# CAMERA/Subject14Activity6Trial1Camera1/2018-07-11T10_59_00.151565.png : 230000
# CAMERA/Subject14Activity7Trial3Camera1/2018-07-11T11_05_31.110521.png : 235000
# CAMERA/Subject14Activity10Trial2Camera1/2018-07-11T11_12_41.447706.png : 240000
# CAMERA/Subject15Activity3Trial2Camera1/2018-07-11T17_52_26.105948.png : 245000
# CAMERA/Subject15Activity7Trial1Camera1/2018-07-11T18_00_51.863436.png : 250000
# CAMERA/Subject15Activity8Trial3Camera1/2018-07-11T18_07_17.402482.png : 255000
# CAMERA/Subject15Activity11Trial3Camera1/2018-07-11T18_17_06.234162.png : 260000
# CAMERA/Subject16Activity6Trial2Camera1/2018-07-12T11_00_46.101964.png : 265000
# CAMERA/Subject16Activity8Trial1Camera1/2018-07-12T11_06_42.822245.png : 270000
# CAMERA/Subject16Activity11Trial1Camera1/2018-07-12T11_15_41.028370.png : 275000
# CAMERA/Subject17Activity6Trial1Camera1/2018-07-12T12_01_16.393232.png : 280000
# CAMERA/Subject17Activity7Trial2Camera1/2018-07-12T12_05_57.215759.png : 285000
# CAMERA/Subject17Activity10Trial1Camera1/2018-07-12T12_13_28.332030.png : 290000

# %%
size = '32x32'
cam = '1'
image = 'Sensor + Image' + '/' + 'image_' + cam +  '.npy'     
# name = 'Camera + Label' + '/' + size + '/' + 'name_' + cam + '(' + size + ')' + '.npy'     
name = 'Sensor + Image' + '/' + 'name_' + cam +  '.npy'  

name_1 = handle_name(path_1)

np.save(image, img_1)
np.save(name, name_1)

# %%
start_sub = 1
end_sub  = 17
start_act = 1
end_act = 11
start_cam = 2
end_cam = 2

DesiredWidth = 32
DesiredHeight = 32 

img_2, path_2 = load_img(start_sub ,   end_sub,
             start_act , end_act  ,
             start_cam ,   end_cam , DesiredWidth, DesiredHeight )
# Out:
# CAMERA/Subject1Activity6Trial2Camera2/2018-07-04T12_12_01.821800.png : 5000
# CAMERA/Subject1Activity8Trial1Camera2/2018-07-04T12_17_22.832033.png : 10000
# CAMERA/Subject1Activity11Trial1Camera2/2018-07-04T12_24_58.704636.png : 15000
# CAMERA/Subject2Activity4Trial3Camera2/2018-07-11T13_43_26.285138.png : 20000
# CAMERA/Subject2Activity7Trial2Camera2/2018-07-11T13_50_50.004135.png : 25000
# CAMERA/Subject2Activity9Trial1Camera2/2018-07-11T13_56_53.362931.png : 30000
# CAMERA/Subject3Activity1Trial2Camera2/2018-07-05T12_06_01.688633.png : 35000
# CAMERA/Subject3Activity6Trial3Camera2/2018-07-05T12_13_33.475186.png : 40000
# CAMERA/Subject3Activity8Trial1Camera2/2018-07-05T12_18_49.128592.png : 45000
# CAMERA/Subject3Activity11Trial1Camera2/2018-07-05T12_26_39.647046.png : 50000
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.4508017.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.2377235.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.9712772.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.6481190.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.4515847.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.0812561.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_21.1366675.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.3452957.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.5515526.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.5901790.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.7776921.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.2467270.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.9236500.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.3445130.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.3881089.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.1384530.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.0855870.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.4969246.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.7015424.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.9170673.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.1333978.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.5899592.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.4004435.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.0873125.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.1848585.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_21.0384009.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.9792382.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.6483395.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.0194078.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.8679970.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.8667146.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.7664430.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.2828442.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.9208603.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_21.0905398.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.3966523.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.8058265.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.1870625.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.8729491.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.5004141.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.0326237.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.0226372.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.9649805.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.7142955.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.7466689.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.3439914.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.4967048.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.1885876.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_21.2419540.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.1377314.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.6534135.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.2781119.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.6061987.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.7125110.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.2329915.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_18.2948555.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_19.5458413.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.8248185.png : Invalid image
#  CAMERA/Subject4Activity1Trial1Camera2/Subject4Activity1Trial1Camera2Synced/2018-07-10T13_27_20.5440561.png : Invalid image
#  CAMERA/Subject4Activity1Trial3Camera2/2018-07-10T13_28_13.6861355 - copi.png : Invalid image
# CAMERA/Subject4Activity5Trial2Camera2/2018-07-10T13_32_39.725737.png : 55000
# CAMERA/Subject4Activity7Trial2Camera2/2018-07-10T13_38_13.178119.png : 60000
# CAMERA/Subject4Activity8Trial3Camera2/2018-07-10T13_42_34.612386.png : 65000
# CAMERA/Subject4Activity11Trial3Camera2/2018-07-10T13_49_53.489779.png : 70000
# CAMERA/Subject5Activity6Trial2Camera2/2018-07-06T10_50_26.992948.png : 75000
# CAMERA/Subject5Activity8Trial1Camera2/2018-07-06T10_56_07.188393.png : 80000
# CAMERA/Subject5Activity10Trial3Camera2/2018-07-06T11_02_53.332440.png : 85000
# CAMERA/Subject6Activity3Trial3Camera2/2018-07-06T11_46_11.831506.png : 90000
# CAMERA/Subject6Activity7Trial2Camera2/2018-07-06T11_55_23.354464.png : 95000
# ----------------------------NO SHAPE---------------------------------
# CAMERA/Subject6Activity10Trial2Camera2/2018-07-06T12_03_20.967517.png : 100000
#  CAMERA/Subject7Activity1Trial1Camera2/2018-07-06T12_42_47.2340654 - copi.png : Invalid image
# CAMERA/Subject7Activity4Trial1Camera2/2018-07-06T12_46_39.619964.png : 105000
# CAMERA/Subject7Activity7Trial1Camera2/2018-07-06T12_52_58.705510.png : 110000
# CAMERA/Subject7Activity8Trial3Camera2/2018-07-06T12_58_56.729045.png : 115000
# CAMERA/Subject7Activity11Trial2Camera2/2018-07-06T13_06_15.996593.png : 120000
# CAMERA/Subject8Activity6Trial1Camera2/2018-07-09T10_26_59.278811.png : 125000
# CAMERA/Subject8Activity7Trial3Camera2/2018-07-09T10_31_53.046824.png : 130000
# CAMERA/Subject8Activity10Trial2Camera2/2018-07-09T10_38_13.508863.png : 135000
# ----------------------------NULL---------------------------------
# ----------------------------NULL---------------------------------
# CAMERA/Subject9Activity6Trial1Camera2/2018-07-09T12_09_24.486911.png : 140000
# CAMERA/Subject9Activity7Trial2Camera2/2018-07-09T12_14_01.290466.png : 145000
# CAMERA/Subject9Activity10Trial1Camera2/2018-07-09T12_21_06.256640.png : 150000
# CAMERA/Subject10Activity1Trial2Camera2/2018-07-10T13_08_50.964573.png : 155000
# CAMERA/Subject10Activity6Trial3Camera2/2018-07-09T13_46_04.357566.png : 160000
# CAMERA/Subject10Activity8Trial1Camera2/2018-07-09T13_51_12.499379.png : 165000
# CAMERA/Subject10Activity11Trial1Camera2/2018-07-09T13_59_47.560582.png : 170000
# CAMERA/Subject11Activity5Trial3Camera2/2018-07-10T10_41_29.484124.png : 175000
# CAMERA/Subject11Activity7Trial2Camera2/2018-07-10T10_47_07.382927.png : 180000
# CAMERA/Subject11Activity8Trial3Camera2/2018-07-10T10_52_07.169756.png : 185000
# CAMERA/Subject11Activity11Trial3Camera2/2018-07-10T12_24_53.530337.png : 190000
# CAMERA/Subject12Activity6Trial2Camera2/2018-07-10T11_40_57.002830.png : 195000
# CAMERA/Subject12Activity7Trial3Camera2/2018-07-10T11_45_33.126045.png : 200000
# CAMERA/Subject12Activity10Trial2Camera2/2018-07-10T11_52_21.335222.png : 205000
# CAMERA/Subject13Activity2Trial3Camera2/2018-07-11T12_45_13.711434.png : 210000
# CAMERA/Subject13Activity7Trial1Camera2/2018-07-11T12_53_24.343938.png : 215000
# CAMERA/Subject13Activity8Trial2Camera2/2018-07-11T12_58_17.662973.png : 220000
# CAMERA/Subject13Activity11Trial2Camera2/2018-07-11T13_04_50.104309.png : 225000
# CAMERA/Subject14Activity6Trial1Camera2/2018-07-11T10_58_36.830522.png : 230000
# CAMERA/Subject14Activity7Trial3Camera2/2018-07-11T11_05_30.615662.png : 235000
# CAMERA/Subject14Activity10Trial2Camera2/2018-07-11T11_12_45.786581.png : 240000
# CAMERA/Subject15Activity3Trial1Camera2/2018-07-11T17_51_57.678075.png : 245000
# CAMERA/Subject15Activity7Trial1Camera2/2018-07-11T18_00_29.100253.png : 250000
# CAMERA/Subject15Activity8Trial3Camera2/2018-07-11T18_07_47.069612.png : 255000
# CAMERA/Subject15Activity11Trial2Camera2/2018-07-11T18_16_03.418142.png : 260000
# CAMERA/Subject16Activity6Trial2Camera2/2018-07-12T11_01_05.835383.png : 265000
# CAMERA/Subject16Activity8Trial1Camera2/2018-07-12T11_06_29.808633.png : 270000
# CAMERA/Subject16Activity11Trial1Camera2/2018-07-12T11_15_31.374117.png : 275000
# CAMERA/Subject17Activity5Trial3Camera2/2018-07-12T12_00_10.214343.png : 280000
# CAMERA/Subject17Activity7Trial2Camera2/2018-07-12T12_05_33.797182.png : 285000
# CAMERA/Subject17Activity9Trial3Camera2/2018-07-12T12_12_42.204337.png : 290000

# %%
print(len(img_1))
print(len(name_1))
print(len(img_2))
print(len(name_2))
# Out:
# 294678
# 294678
# 294678
# 294678

# %%
ind1 = np.arange(0,294678)
red_in1 = ind1[~np.isin(name_1,name_2)]

name_1d =  np.delete(name_1, red_in1[0])
img_1d = np.delete(img_1, red_in1[0], axis = 0)

# %%
ind2 = np.arange(0,294678)
red_in2 = ind2[~np.isin(name_2,name_1)]

name_2d =  np.delete(name_2, red_in2[0])
img_2d = np.delete(img_2, red_in2[0], axis = 0)

# %%
(name_1d == name_2d).all()
# Out:
# True

# %%
label_1 = Time_Label.loc[name_1d].values
label_2 = Time_Label.loc[name_2d].values

# %%
print(len(img_1d))
print(len(name_1d))
print(len(label_1))
print(len(img_2d))
print(len(name_2d))
print(len(label_2))
# Out:
# 294677
# 294677
# 294677
# 294677
# 294677
# 294677

# %%
cam = '1'

image = 'Sensor + Image' + '/' + 'image_' + cam +  '.npy'       
name = 'Sensor + Image' + '/' + 'name_' + cam +  '.npy'
label = 'Sensor + Image' + '/' + 'label_' + cam +  '.npy'


np.save(image, img_1d)
np.save(name, name_1d)
np.save(label, label_1)


cam = '2'
image = 'Sensor + Image' + '/' + 'image_' + cam +  '.npy'       
name = 'Sensor + Image' + '/' + 'name_' + cam +  '.npy'
label = 'Sensor + Image' + '/' + 'label_' + cam +  '.npy'

np.save(image, img_2d)
np.save(name, name_2d)
np.save(label, label_2)
